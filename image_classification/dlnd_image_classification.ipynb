# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np
import pandas as pd

# Explore the dataset
batch_id = 1
sample_id = 11
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 11:
# Image - Min Value: 0 Max Value: 254
# Image - Shape: (32, 32, 3)
# Label - Label Id: 7 Name: horse

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return np.array(x/255)
    
    #return None


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
global labels

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    #Started writing my own function to do this, but found https://discussions.udacity.com/t/one-hot-need-help/244664/6?u=max25324eaaa5ea3f6b9
    # Many thanks to that person.
    enconding_list = [i for i in range(10)] # generate list 0...9
    encoding = pd.get_dummies(enconding_list) #generate dummies
    x = np.array(x)
    one_hot_labels = np.zeros([x.shape[0], 10]) #generate an aray of zeros
    for i in range(x.shape[0]): # iterate over all arrays in x: x.shape[0] is the length of the array. 
        one_hot_labels[i] = encoding[x[i]] #set the array with the correct encoding. 
    return np.array(one_hot_labels) #return one hot encoded array.



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    x = tf.placeholder(shape=(None, *image_shape), name='x', dtype=tf.float32)
    return (x)


def neural_net_label_input(n_classes):
    y = tf.placeholder(shape=(None, n_classes), name='y', dtype=tf.float32)
    return (y)


def neural_net_keep_prob_input():
    keep_prob = tf.placeholder(name='keep_prob', dtype=tf.float32)
    return (keep_prob)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    weight = tf.Variable(tf.truncated_normal((conv_ksize[0], conv_ksize[1], x_tensor.get_shape().as_list()[-1], conv_num_outputs), mean=0.0, stddev=0.2)) # (height, width, input_depth, output_depth)
    bias = tf.Variable(tf.zeros(conv_num_outputs))

    conv_layer = tf.nn.conv2d(x_tensor, weight, [1,conv_strides[0],conv_strides[1],1], padding='SAME')
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    conv_layer = tf.nn.relu(conv_layer)


    # Apply Max Pooling
    conv_layer = tf.nn.max_pool(conv_layer, [1 , pool_ksize[0], pool_ksize[1], 1], [1, pool_strides[0], pool_strides[1], 1],
    padding='SAME')

    return conv_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    batch_size = x_tensor.get_shape().as_list()[0]
    width = x_tensor.get_shape().as_list()[1]
    height = x_tensor.get_shape().as_list()[2]
    depth = x_tensor.get_shape().as_list()[3]
    elements = width*height*depth

    return tf.reshape(x_tensor, shape = [-1,elements])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weight = tf.Variable(tf.truncated_normal(( x_tensor.get_shape().as_list()[-1], num_outputs), mean=0.0, stddev=0.1)) # (height, width, input_depth, output_depth)
    bias = tf.Variable(tf.zeros(num_outputs))
    x_tensor = tf.add(tf.matmul(x_tensor,  weight), bias)

    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weight = tf.Variable(tf.truncated_normal(( x_tensor.get_shape().as_list()[-1], num_outputs), mean=0.0, stddev=0.1)) # (height, width, input_depth, output_depth)
    bias = tf.Variable(tf.zeros(num_outputs))
    x_tensor = tf.add(tf.matmul(x_tensor,  weight), bias)

    return x_tensor

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """

    
    #define the params once here, then refer to using index number
    conv_num_outputs = [8,64,128]
    conv_ksize = ((2,2), (3,3), (8,8), (1,1))
    conv_strides = ((1,1), (1,1), (1,1))
    pool_ksize = ((2,2), (3,3), (8,8))
    pool_strides = ((1,1), (1,1), (1,1))
    num_outputs = [324, 64,10]

        
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    #    Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    for i in range(2):
        x  = conv2d_maxpool(x, conv_num_outputs[i] , conv_ksize[i] , conv_strides[i] , pool_ksize[i] , pool_strides[i] )
        if i == 0:
            tf.nn.dropout(x, keep_prob)
        else:
            tf.nn.dropout(x, 0.15)
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x = flatten(x)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    for i in range(0):
        x = fully_conn(x, num_outputs[i])
        tf.nn.dropout(x, keep_prob)

    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
            
    #for i in range(1):
    x = output(x, 10)
    # TODO: return output --- this is a logit. No activation is done on this
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = sess.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1})
    validation = sess.run(accuracy, feed_dict={x: valid_features, y: valid_labels,  keep_prob: 1})
    print('loss', loss, 'accuracy', validation)

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 150
batch_size = 2048
keep_probability = 0.35

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
print(keep_probability)
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# 0.35
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  loss 21.5703 accuracy 0.1232
# Epoch  2, CIFAR-10 Batch 1:  loss 12.3174 accuracy 0.1166
# Epoch  3, CIFAR-10 Batch 1:  loss 7.36481 accuracy 0.1498
# Epoch  4, CIFAR-10 Batch 1:  loss 4.73189 accuracy 0.1326
# Epoch  5, CIFAR-10 Batch 1:  loss 3.24641 accuracy 0.1804
# Epoch  6, CIFAR-10 Batch 1:  loss 2.99912 accuracy 0.2012
# Epoch  7, CIFAR-10 Batch 1:  loss 2.63633 accuracy 0.2332
# Epoch  8, CIFAR-10 Batch 1:  loss 2.35041 accuracy 0.2294
# Epoch  9, CIFAR-10 Batch 1:  loss 2.04625 accuracy 0.28
# Epoch 10, CIFAR-10 Batch 1:  loss 1.93436 accuracy 0.3026
# Epoch 11, CIFAR-10 Batch 1:  loss 1.80155 accuracy 0.323
# Epoch 12, CIFAR-10 Batch 1:  loss 1.71343 accuracy 0.3442
# Epoch 13, CIFAR-10 Batch 1:  loss 1.61776 accuracy 0.3776
# Epoch 14, CIFAR-10 Batch 1:  loss 1.53807 accuracy 0.3876
# Epoch 15, CIFAR-10 Batch 1:  loss 1.46619 accuracy 0.405
# Epoch 16, CIFAR-10 Batch 1:  loss 1.39297 accuracy 0.418
# Epoch 17, CIFAR-10 Batch 1:  loss 1.32814 accuracy 0.4292
# Epoch 18, CIFAR-10 Batch 1:  loss 1.2715 accuracy 0.4362
# Epoch 19, CIFAR-10 Batch 1:  loss 1.22232 accuracy 0.4476
# Epoch 20, CIFAR-10 Batch 1:  loss 1.17314 accuracy 0.453
# Epoch 21, CIFAR-10 Batch 1:  loss 1.12962 accuracy 0.46
# Epoch 22, CIFAR-10 Batch 1:  loss 1.08554 accuracy 0.4684
# Epoch 23, CIFAR-10 Batch 1:  loss 1.0453 accuracy 0.472
# Epoch 24, CIFAR-10 Batch 1:  loss 1.0069 accuracy 0.479
# Epoch 25, CIFAR-10 Batch 1:  loss 0.97099 accuracy 0.4866
# Epoch 26, CIFAR-10 Batch 1:  loss 0.937955 accuracy 0.4946
# Epoch 27, CIFAR-10 Batch 1:  loss 0.906747 accuracy 0.5006
# Epoch 28, CIFAR-10 Batch 1:  loss 0.87769 accuracy 0.5014
# Epoch 29, CIFAR-10 Batch 1:  loss 0.850373 accuracy 0.5042
# Epoch 30, CIFAR-10 Batch 1:  loss 0.824392 accuracy 0.5088
# Epoch 31, CIFAR-10 Batch 1:  loss 0.799512 accuracy 0.5124
# Epoch 32, CIFAR-10 Batch 1:  loss 0.776108 accuracy 0.5154
# Epoch 33, CIFAR-10 Batch 1:  loss 0.753809 accuracy 0.5168
# Epoch 34, CIFAR-10 Batch 1:  loss 0.732438 accuracy 0.5196
# Epoch 35, CIFAR-10 Batch 1:  loss 0.711825 accuracy 0.522
# Epoch 36, CIFAR-10 Batch 1:  loss 0.691475 accuracy 0.524
# Epoch 37, CIFAR-10 Batch 1:  loss 0.671237 accuracy 0.5234
# Epoch 38, CIFAR-10 Batch 1:  loss 0.651528 accuracy 0.5278
# Epoch 39, CIFAR-10 Batch 1:  loss 0.632982 accuracy 0.5316
# Epoch 40, CIFAR-10 Batch 1:  loss 0.615595 accuracy 0.5322
# Epoch 41, CIFAR-10 Batch 1:  loss 0.599449 accuracy 0.5332
# Epoch 42, CIFAR-10 Batch 1:  loss 0.584255 accuracy 0.5332
# Epoch 43, CIFAR-10 Batch 1:  loss 0.569704 accuracy 0.535
# Epoch 44, CIFAR-10 Batch 1:  loss 0.555744 accuracy 0.5334
# Epoch 45, CIFAR-10 Batch 1:  loss 0.542197 accuracy 0.5346
# Epoch 46, CIFAR-10 Batch 1:  loss 0.529181 accuracy 0.5346
# Epoch 47, CIFAR-10 Batch 1:  loss 0.516513 accuracy 0.5362
# Epoch 48, CIFAR-10 Batch 1:  loss 0.504056 accuracy 0.5382
# Epoch 49, CIFAR-10 Batch 1:  loss 0.491699 accuracy 0.5388
# Epoch 50, CIFAR-10 Batch 1:  loss 0.479437 accuracy 0.5402

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  loss 8.05284 accuracy 0.1358
# Epoch  1, CIFAR-10 Batch 2:  loss 4.10513 accuracy 0.1314
# Epoch  1, CIFAR-10 Batch 3:  loss 3.45221 accuracy 0.14
# Epoch  1, CIFAR-10 Batch 4:  loss 2.92952 accuracy 0.1702
# Epoch  1, CIFAR-10 Batch 5:  loss 2.26523 accuracy 0.2196
# Epoch  2, CIFAR-10 Batch 1:  loss 2.23932 accuracy 0.2464
# Epoch  2, CIFAR-10 Batch 2:  loss 2.04285 accuracy 0.2584
# Epoch  2, CIFAR-10 Batch 3:  loss 1.93071 accuracy 0.2938
# Epoch  2, CIFAR-10 Batch 4:  loss 1.83204 accuracy 0.3298
# Epoch  2, CIFAR-10 Batch 5:  loss 1.79426 accuracy 0.3514
# Epoch  3, CIFAR-10 Batch 1:  loss 1.7148 accuracy 0.3792
# Epoch  3, CIFAR-10 Batch 2:  loss 1.60283 accuracy 0.4114
# Epoch  3, CIFAR-10 Batch 3:  loss 1.53292 accuracy 0.4272
# Epoch  3, CIFAR-10 Batch 4:  loss 1.50382 accuracy 0.4474
# Epoch  3, CIFAR-10 Batch 5:  loss 1.49009 accuracy 0.4574
# Epoch  4, CIFAR-10 Batch 1:  loss 1.45214 accuracy 0.4772
# Epoch  4, CIFAR-10 Batch 2:  loss 1.37166 accuracy 0.485
# Epoch  4, CIFAR-10 Batch 3:  loss 1.33167 accuracy 0.4974
# Epoch  4, CIFAR-10 Batch 4:  loss 1.33084 accuracy 0.504
# Epoch  4, CIFAR-10 Batch 5:  loss 1.31864 accuracy 0.5102
# Epoch  5, CIFAR-10 Batch 1:  loss 1.31864 accuracy 0.5148
# Epoch  5, CIFAR-10 Batch 2:  loss 1.26686 accuracy 0.52
# Epoch  5, CIFAR-10 Batch 3:  loss 1.22338 accuracy 0.5304
# Epoch  5, CIFAR-10 Batch 4:  loss 1.22997 accuracy 0.5324
# Epoch  5, CIFAR-10 Batch 5:  loss 1.212 accuracy 0.5366
# Epoch  6, CIFAR-10 Batch 1:  loss 1.22976 accuracy 0.5414
# Epoch  6, CIFAR-10 Batch 2:  loss 1.19453 accuracy 0.5456
# Epoch  6, CIFAR-10 Batch 3:  loss 1.14692 accuracy 0.5538
# Epoch  6, CIFAR-10 Batch 4:  loss 1.15595 accuracy 0.5522
# Epoch  6, CIFAR-10 Batch 5:  loss 1.13085 accuracy 0.5558
# Epoch  7, CIFAR-10 Batch 1:  loss 1.16152 accuracy 0.563
# Epoch  7, CIFAR-10 Batch 2:  loss 1.13057 accuracy 0.5634
# Epoch  7, CIFAR-10 Batch 3:  loss 1.08539 accuracy 0.5664
# Epoch  7, CIFAR-10 Batch 4:  loss 1.0936 accuracy 0.5714
# Epoch  7, CIFAR-10 Batch 5:  loss 1.06374 accuracy 0.5702
# Epoch  8, CIFAR-10 Batch 1:  loss 1.10417 accuracy 0.5768
# Epoch  8, CIFAR-10 Batch 2:  loss 1.07316 accuracy 0.5724
# Epoch  8, CIFAR-10 Batch 3:  loss 1.03004 accuracy 0.5768
# Epoch  8, CIFAR-10 Batch 4:  loss 1.03842 accuracy 0.5806
# Epoch  8, CIFAR-10 Batch 5:  loss 1.00387 accuracy 0.5812
# Epoch  9, CIFAR-10 Batch 1:  loss 1.05693 accuracy 0.59
# Epoch  9, CIFAR-10 Batch 2:  loss 1.02299 accuracy 0.5852
# Epoch  9, CIFAR-10 Batch 3:  loss 0.978699 accuracy 0.5908
# Epoch  9, CIFAR-10 Batch 4:  loss 0.989066 accuracy 0.5882
# Epoch  9, CIFAR-10 Batch 5:  loss 0.950233 accuracy 0.5922
# Epoch 10, CIFAR-10 Batch 1:  loss 1.01318 accuracy 0.6
# Epoch 10, CIFAR-10 Batch 2:  loss 0.976426 accuracy 0.5946
# Epoch 10, CIFAR-10 Batch 3:  loss 0.92991 accuracy 0.5978
# Epoch 10, CIFAR-10 Batch 4:  loss 0.947703 accuracy 0.5938
# Epoch 10, CIFAR-10 Batch 5:  loss 0.904616 accuracy 0.6004
# Epoch 11, CIFAR-10 Batch 1:  loss 0.972299 accuracy 0.6072
# Epoch 11, CIFAR-10 Batch 2:  loss 0.934956 accuracy 0.6016
# Epoch 11, CIFAR-10 Batch 3:  loss 0.886299 accuracy 0.6032
# Epoch 11, CIFAR-10 Batch 4:  loss 0.912075 accuracy 0.6004
# Epoch 11, CIFAR-10 Batch 5:  loss 0.864282 accuracy 0.6064
# Epoch 12, CIFAR-10 Batch 1:  loss 0.9355 accuracy 0.6126
# Epoch 12, CIFAR-10 Batch 2:  loss 0.898445 accuracy 0.61
# Epoch 12, CIFAR-10 Batch 3:  loss 0.84757 accuracy 0.612
# Epoch 12, CIFAR-10 Batch 4:  loss 0.879009 accuracy 0.6042
# Epoch 12, CIFAR-10 Batch 5:  loss 0.828543 accuracy 0.6156
# Epoch 13, CIFAR-10 Batch 1:  loss 0.901481 accuracy 0.6186
# Epoch 13, CIFAR-10 Batch 2:  loss 0.865932 accuracy 0.6148
# Epoch 13, CIFAR-10 Batch 3:  loss 0.814094 accuracy 0.617
# Epoch 13, CIFAR-10 Batch 4:  loss 0.848322 accuracy 0.6122
# Epoch 13, CIFAR-10 Batch 5:  loss 0.797427 accuracy 0.6176
# Epoch 14, CIFAR-10 Batch 1:  loss 0.871038 accuracy 0.6224
# Epoch 14, CIFAR-10 Batch 2:  loss 0.836543 accuracy 0.619
# Epoch 14, CIFAR-10 Batch 3:  loss 0.784904 accuracy 0.6238
# Epoch 14, CIFAR-10 Batch 4:  loss 0.818377 accuracy 0.6186
# Epoch 14, CIFAR-10 Batch 5:  loss 0.769945 accuracy 0.6216
# Epoch 15, CIFAR-10 Batch 1:  loss 0.843103 accuracy 0.6292
# Epoch 15, CIFAR-10 Batch 2:  loss 0.809609 accuracy 0.6242
# Epoch 15, CIFAR-10 Batch 3:  loss 0.758189 accuracy 0.6274
# Epoch 15, CIFAR-10 Batch 4:  loss 0.790151 accuracy 0.6224
# Epoch 15, CIFAR-10 Batch 5:  loss 0.744625 accuracy 0.6276
# Epoch 16, CIFAR-10 Batch 1:  loss 0.818449 accuracy 0.6316
# Epoch 16, CIFAR-10 Batch 2:  loss 0.783908 accuracy 0.6264
# Epoch 16, CIFAR-10 Batch 3:  loss 0.734105 accuracy 0.629
# Epoch 16, CIFAR-10 Batch 4:  loss 0.763238 accuracy 0.625
# Epoch 16, CIFAR-10 Batch 5:  loss 0.720883 accuracy 0.6326
# Epoch 17, CIFAR-10 Batch 1:  loss 0.796477 accuracy 0.6354
# Epoch 17, CIFAR-10 Batch 2:  loss 0.75953 accuracy 0.631
# Epoch 17, CIFAR-10 Batch 3:  loss 0.711 accuracy 0.629
# Epoch 17, CIFAR-10 Batch 4:  loss 0.738011 accuracy 0.6286
# Epoch 17, CIFAR-10 Batch 5:  loss 0.697306 accuracy 0.6368
# Epoch 18, CIFAR-10 Batch 1:  loss 0.774566 accuracy 0.6366
# Epoch 18, CIFAR-10 Batch 2:  loss 0.736123 accuracy 0.6338
# Epoch 18, CIFAR-10 Batch 3:  loss 0.689235 accuracy 0.6302
# Epoch 18, CIFAR-10 Batch 4:  loss 0.713888 accuracy 0.634
# Epoch 18, CIFAR-10 Batch 5:  loss 0.674761 accuracy 0.6422
# Epoch 19, CIFAR-10 Batch 1:  loss 0.753263 accuracy 0.6408
# Epoch 19, CIFAR-10 Batch 2:  loss 0.714156 accuracy 0.6384
# Epoch 19, CIFAR-10 Batch 3:  loss 0.668641 accuracy 0.6356
# Epoch 19, CIFAR-10 Batch 4:  loss 0.691523 accuracy 0.6366
# Epoch 19, CIFAR-10 Batch 5:  loss 0.653954 accuracy 0.6424
# Epoch 20, CIFAR-10 Batch 1:  loss 0.732016 accuracy 0.6448
# Epoch 20, CIFAR-10 Batch 2:  loss 0.693308 accuracy 0.6404
# Epoch 20, CIFAR-10 Batch 3:  loss 0.649896 accuracy 0.6386
# Epoch 20, CIFAR-10 Batch 4:  loss 0.669728 accuracy 0.6388
# Epoch 20, CIFAR-10 Batch 5:  loss 0.63458 accuracy 0.6456
# Epoch 21, CIFAR-10 Batch 1:  loss 0.712405 accuracy 0.6454
# Epoch 21, CIFAR-10 Batch 2:  loss 0.674189 accuracy 0.643
# Epoch 21, CIFAR-10 Batch 3:  loss 0.631969 accuracy 0.6416
# Epoch 21, CIFAR-10 Batch 4:  loss 0.64926 accuracy 0.6416
# Epoch 21, CIFAR-10 Batch 5:  loss 0.61659 accuracy 0.65
# Epoch 22, CIFAR-10 Batch 1:  loss 0.693218 accuracy 0.6468
# Epoch 22, CIFAR-10 Batch 2:  loss 0.655631 accuracy 0.6438
# Epoch 22, CIFAR-10 Batch 3:  loss 0.61478 accuracy 0.6444
# Epoch 22, CIFAR-10 Batch 4:  loss 0.629397 accuracy 0.6448
# Epoch 22, CIFAR-10 Batch 5:  loss 0.599215 accuracy 0.6508
# Epoch 23, CIFAR-10 Batch 1:  loss 0.674967 accuracy 0.648
# Epoch 23, CIFAR-10 Batch 2:  loss 0.637644 accuracy 0.6432
# Epoch 23, CIFAR-10 Batch 3:  loss 0.598726 accuracy 0.6462
# Epoch 23, CIFAR-10 Batch 4:  loss 0.610318 accuracy 0.6484
# Epoch 23, CIFAR-10 Batch 5:  loss 0.58234 accuracy 0.6522
# Epoch 24, CIFAR-10 Batch 1:  loss 0.657319 accuracy 0.65
# Epoch 24, CIFAR-10 Batch 2:  loss 0.619913 accuracy 0.6456
# Epoch 24, CIFAR-10 Batch 3:  loss 0.582468 accuracy 0.648
# Epoch 24, CIFAR-10 Batch 4:  loss 0.591804 accuracy 0.6504
# Epoch 24, CIFAR-10 Batch 5:  loss 0.566109 accuracy 0.6522
# Epoch 25, CIFAR-10 Batch 1:  loss 0.640931 accuracy 0.6506
# Epoch 25, CIFAR-10 Batch 2:  loss 0.602681 accuracy 0.6484
# Epoch 25, CIFAR-10 Batch 3:  loss 0.566997 accuracy 0.6492
# Epoch 25, CIFAR-10 Batch 4:  loss 0.574192 accuracy 0.6516
# Epoch 25, CIFAR-10 Batch 5:  loss 0.550539 accuracy 0.6524
# Epoch 26, CIFAR-10 Batch 1:  loss 0.625047 accuracy 0.6498
# Epoch 26, CIFAR-10 Batch 2:  loss 0.585974 accuracy 0.6484
# Epoch 26, CIFAR-10 Batch 3:  loss 0.552034 accuracy 0.6518
# Epoch 26, CIFAR-10 Batch 4:  loss 0.557505 accuracy 0.6526
# Epoch 26, CIFAR-10 Batch 5:  loss 0.535692 accuracy 0.654
# Epoch 27, CIFAR-10 Batch 1:  loss 0.609308 accuracy 0.6502
# Epoch 27, CIFAR-10 Batch 2:  loss 0.56993 accuracy 0.6502
# Epoch 27, CIFAR-10 Batch 3:  loss 0.537497 accuracy 0.6542
# Epoch 27, CIFAR-10 Batch 4:  loss 0.542051 accuracy 0.654
# Epoch 27, CIFAR-10 Batch 5:  loss 0.521535 accuracy 0.6556
# Epoch 28, CIFAR-10 Batch 1:  loss 0.594253 accuracy 0.6496
# Epoch 28, CIFAR-10 Batch 2:  loss 0.554743 accuracy 0.6506
# Epoch 28, CIFAR-10 Batch 3:  loss 0.523685 accuracy 0.654
# Epoch 28, CIFAR-10 Batch 4:  loss 0.527462 accuracy 0.6538
# Epoch 28, CIFAR-10 Batch 5:  loss 0.507744 accuracy 0.6552
# Epoch 29, CIFAR-10 Batch 1:  loss 0.579566 accuracy 0.6502
# Epoch 29, CIFAR-10 Batch 2:  loss 0.540079 accuracy 0.6528
# Epoch 29, CIFAR-10 Batch 3:  loss 0.51043 accuracy 0.6542
# Epoch 29, CIFAR-10 Batch 4:  loss 0.513367 accuracy 0.6554
# Epoch 29, CIFAR-10 Batch 5:  loss 0.494477 accuracy 0.6558
# Epoch 30, CIFAR-10 Batch 1:  loss 0.565557 accuracy 0.6514
# Epoch 30, CIFAR-10 Batch 2:  loss 0.525985 accuracy 0.6534
# Epoch 30, CIFAR-10 Batch 3:  loss 0.497586 accuracy 0.6552
# Epoch 30, CIFAR-10 Batch 4:  loss 0.49991 accuracy 0.6564
# Epoch 30, CIFAR-10 Batch 5:  loss 0.481811 accuracy 0.656
# Epoch 31, CIFAR-10 Batch 1:  loss 0.552027 accuracy 0.6512
# Epoch 31, CIFAR-10 Batch 2:  loss 0.512275 accuracy 0.6528
# Epoch 31, CIFAR-10 Batch 3:  loss 0.485079 accuracy 0.655
# Epoch 31, CIFAR-10 Batch 4:  loss 0.487197 accuracy 0.659
# Epoch 31, CIFAR-10 Batch 5:  loss 0.469579 accuracy 0.6554
# Epoch 32, CIFAR-10 Batch 1:  loss 0.538772 accuracy 0.6524
# Epoch 32, CIFAR-10 Batch 2:  loss 0.499057 accuracy 0.6518
# Epoch 32, CIFAR-10 Batch 3:  loss 0.473372 accuracy 0.6554
# Epoch 32, CIFAR-10 Batch 4:  loss 0.475361 accuracy 0.6592
# Epoch 32, CIFAR-10 Batch 5:  loss 0.457932 accuracy 0.6576
# Epoch 33, CIFAR-10 Batch 1:  loss 0.525946 accuracy 0.6528
# Epoch 33, CIFAR-10 Batch 2:  loss 0.486395 accuracy 0.6508
# Epoch 33, CIFAR-10 Batch 3:  loss 0.462011 accuracy 0.6562
# Epoch 33, CIFAR-10 Batch 4:  loss 0.464087 accuracy 0.66
# Epoch 33, CIFAR-10 Batch 5:  loss 0.446474 accuracy 0.659
# Epoch 34, CIFAR-10 Batch 1:  loss 0.513146 accuracy 0.6524
# Epoch 34, CIFAR-10 Batch 2:  loss 0.474039 accuracy 0.6516
# Epoch 34, CIFAR-10 Batch 3:  loss 0.451175 accuracy 0.6574
# Epoch 34, CIFAR-10 Batch 4:  loss 0.453237 accuracy 0.6606
# Epoch 34, CIFAR-10 Batch 5:  loss 0.435383 accuracy 0.659
# Epoch 35, CIFAR-10 Batch 1:  loss 0.500716 accuracy 0.6528
# Epoch 35, CIFAR-10 Batch 2:  loss 0.462303 accuracy 0.6524
# Epoch 35, CIFAR-10 Batch 3:  loss 0.440834 accuracy 0.6568
# Epoch 35, CIFAR-10 Batch 4:  loss 0.44285 accuracy 0.6598
# Epoch 35, CIFAR-10 Batch 5:  loss 0.424569 accuracy 0.6576
# Epoch 36, CIFAR-10 Batch 1:  loss 0.488467 accuracy 0.6534
# Epoch 36, CIFAR-10 Batch 2:  loss 0.45099 accuracy 0.6526
# Epoch 36, CIFAR-10 Batch 3:  loss 0.431002 accuracy 0.658
# Epoch 36, CIFAR-10 Batch 4:  loss 0.432302 accuracy 0.661
# Epoch 36, CIFAR-10 Batch 5:  loss 0.414046 accuracy 0.6588
# Epoch 37, CIFAR-10 Batch 1:  loss 0.476684 accuracy 0.6546
# Epoch 37, CIFAR-10 Batch 2:  loss 0.44019 accuracy 0.6524
# Epoch 37, CIFAR-10 Batch 3:  loss 0.421124 accuracy 0.6584
# Epoch 37, CIFAR-10 Batch 4:  loss 0.421516 accuracy 0.6612
# Epoch 37, CIFAR-10 Batch 5:  loss 0.403801 accuracy 0.6604
# Epoch 38, CIFAR-10 Batch 1:  loss 0.465372 accuracy 0.6554
# Epoch 38, CIFAR-10 Batch 2:  loss 0.429574 accuracy 0.6526
# Epoch 38, CIFAR-10 Batch 3:  loss 0.411292 accuracy 0.6584
# Epoch 38, CIFAR-10 Batch 4:  loss 0.410936 accuracy 0.6616
# Epoch 38, CIFAR-10 Batch 5:  loss 0.394059 accuracy 0.6616
# Epoch 39, CIFAR-10 Batch 1:  loss 0.4544 accuracy 0.6558
# Epoch 39, CIFAR-10 Batch 2:  loss 0.419097 accuracy 0.654
# Epoch 39, CIFAR-10 Batch 3:  loss 0.401498 accuracy 0.6612
# Epoch 39, CIFAR-10 Batch 4:  loss 0.400554 accuracy 0.6602
# Epoch 39, CIFAR-10 Batch 5:  loss 0.384937 accuracy 0.6606
# Epoch 40, CIFAR-10 Batch 1:  loss 0.443654 accuracy 0.6568
# Epoch 40, CIFAR-10 Batch 2:  loss 0.408955 accuracy 0.6562
# Epoch 40, CIFAR-10 Batch 3:  loss 0.392067 accuracy 0.6622
# Epoch 40, CIFAR-10 Batch 4:  loss 0.390887 accuracy 0.6602
# Epoch 40, CIFAR-10 Batch 5:  loss 0.376045 accuracy 0.6604
# Epoch 41, CIFAR-10 Batch 1:  loss 0.433326 accuracy 0.6562
# Epoch 41, CIFAR-10 Batch 2:  loss 0.399308 accuracy 0.6568
# Epoch 41, CIFAR-10 Batch 3:  loss 0.383165 accuracy 0.6624
# Epoch 41, CIFAR-10 Batch 4:  loss 0.381427 accuracy 0.6598
# Epoch 41, CIFAR-10 Batch 5:  loss 0.367676 accuracy 0.6598
# Epoch 42, CIFAR-10 Batch 1:  loss 0.423512 accuracy 0.6574
# Epoch 42, CIFAR-10 Batch 2:  loss 0.390403 accuracy 0.6558
# Epoch 42, CIFAR-10 Batch 3:  loss 0.374609 accuracy 0.6626
# Epoch 42, CIFAR-10 Batch 4:  loss 0.372355 accuracy 0.66
# Epoch 42, CIFAR-10 Batch 5:  loss 0.359459 accuracy 0.6596
# Epoch 43, CIFAR-10 Batch 1:  loss 0.413948 accuracy 0.658
# Epoch 43, CIFAR-10 Batch 2:  loss 0.381708 accuracy 0.6568
# Epoch 43, CIFAR-10 Batch 3:  loss 0.366277 accuracy 0.6634
# Epoch 43, CIFAR-10 Batch 4:  loss 0.363434 accuracy 0.6596
# Epoch 43, CIFAR-10 Batch 5:  loss 0.351679 accuracy 0.6598
# Epoch 44, CIFAR-10 Batch 1:  loss 0.404626 accuracy 0.6582
# Epoch 44, CIFAR-10 Batch 2:  loss 0.37343 accuracy 0.6566
# Epoch 44, CIFAR-10 Batch 3:  loss 0.358392 accuracy 0.663
# Epoch 44, CIFAR-10 Batch 4:  loss 0.354824 accuracy 0.6612
# Epoch 44, CIFAR-10 Batch 5:  loss 0.344334 accuracy 0.6594
# Epoch 45, CIFAR-10 Batch 1:  loss 0.395748 accuracy 0.6568
# Epoch 45, CIFAR-10 Batch 2:  loss 0.365413 accuracy 0.6562
# Epoch 45, CIFAR-10 Batch 3:  loss 0.35062 accuracy 0.6628
# Epoch 45, CIFAR-10 Batch 4:  loss 0.346421 accuracy 0.6608
# Epoch 45, CIFAR-10 Batch 5:  loss 0.337288 accuracy 0.6594
# Epoch 46, CIFAR-10 Batch 1:  loss 0.387415 accuracy 0.6582
# Epoch 46, CIFAR-10 Batch 2:  loss 0.357501 accuracy 0.6558
# Epoch 46, CIFAR-10 Batch 3:  loss 0.342912 accuracy 0.6618
# Epoch 46, CIFAR-10 Batch 4:  loss 0.338262 accuracy 0.6612
# Epoch 46, CIFAR-10 Batch 5:  loss 0.33098 accuracy 0.6584
# Epoch 47, CIFAR-10 Batch 1:  loss 0.379782 accuracy 0.6578
# Epoch 47, CIFAR-10 Batch 2:  loss 0.349739 accuracy 0.6566
# Epoch 47, CIFAR-10 Batch 3:  loss 0.335719 accuracy 0.6614
# Epoch 47, CIFAR-10 Batch 4:  loss 0.330734 accuracy 0.6612
# Epoch 47, CIFAR-10 Batch 5:  loss 0.32569 accuracy 0.6586
# Epoch 48, CIFAR-10 Batch 1:  loss 0.373363 accuracy 0.6584
# Epoch 48, CIFAR-10 Batch 2:  loss 0.34133 accuracy 0.6576
# Epoch 48, CIFAR-10 Batch 3:  loss 0.329695 accuracy 0.6616
# Epoch 48, CIFAR-10 Batch 4:  loss 0.324063 accuracy 0.663
# Epoch 48, CIFAR-10 Batch 5:  loss 0.321085 accuracy 0.6578
# Epoch 49, CIFAR-10 Batch 1:  loss 0.368999 accuracy 0.658
# Epoch 49, CIFAR-10 Batch 2:  loss 0.331438 accuracy 0.66
# Epoch 49, CIFAR-10 Batch 3:  loss 0.326852 accuracy 0.6588
# Epoch 49, CIFAR-10 Batch 4:  loss 0.320388 accuracy 0.6604
# Epoch 49, CIFAR-10 Batch 5:  loss 0.311159 accuracy 0.6592
# Epoch 50, CIFAR-10 Batch 1:  loss 0.37041 accuracy 0.656
# Epoch 50, CIFAR-10 Batch 2:  loss 0.324602 accuracy 0.6612
# Epoch 50, CIFAR-10 Batch 3:  loss 0.316248 accuracy 0.6588
# Epoch 50, CIFAR-10 Batch 4:  loss 0.314234 accuracy 0.6598
# Epoch 50, CIFAR-10 Batch 5:  loss 0.290608 accuracy 0.6666
# Epoch 51, CIFAR-10 Batch 1:  loss 0.373615 accuracy 0.6516
# Epoch 51, CIFAR-10 Batch 2:  loss 0.361635 accuracy 0.6412
# Epoch 51, CIFAR-10 Batch 3:  loss 0.306661 accuracy 0.6604
# Epoch 51, CIFAR-10 Batch 4:  loss 0.302489 accuracy 0.6586
# Epoch 51, CIFAR-10 Batch 5:  loss 0.289424 accuracy 0.6568
# Epoch 52, CIFAR-10 Batch 1:  loss 0.355996 accuracy 0.6518
# Epoch 52, CIFAR-10 Batch 2:  loss 0.324721 accuracy 0.6538
# Epoch 52, CIFAR-10 Batch 3:  loss 0.31698 accuracy 0.654
# Epoch 52, CIFAR-10 Batch 4:  loss 0.317255 accuracy 0.6504
# Epoch 52, CIFAR-10 Batch 5:  loss 0.301677 accuracy 0.6546
# Epoch 53, CIFAR-10 Batch 1:  loss 0.358682 accuracy 0.6538
# Epoch 53, CIFAR-10 Batch 2:  loss 0.326034 accuracy 0.6546
# Epoch 53, CIFAR-10 Batch 3:  loss 0.307412 accuracy 0.6592
# Epoch 53, CIFAR-10 Batch 4:  loss 0.310043 accuracy 0.6504
# Epoch 53, CIFAR-10 Batch 5:  loss 0.294801 accuracy 0.6542
# Epoch 54, CIFAR-10 Batch 1:  loss 0.357788 accuracy 0.6518
# Epoch 54, CIFAR-10 Batch 2:  loss 0.331735 accuracy 0.6578
# Epoch 54, CIFAR-10 Batch 3:  loss 0.312079 accuracy 0.6606
# Epoch 54, CIFAR-10 Batch 4:  loss 0.309399 accuracy 0.6526
# Epoch 54, CIFAR-10 Batch 5:  loss 0.305916 accuracy 0.6538
# Epoch 55, CIFAR-10 Batch 1:  loss 0.378047 accuracy 0.6504
# Epoch 55, CIFAR-10 Batch 2:  loss 0.382346 accuracy 0.6452
# Epoch 55, CIFAR-10 Batch 3:  loss 0.333374 accuracy 0.653
# Epoch 55, CIFAR-10 Batch 4:  loss 0.303024 accuracy 0.6582
# Epoch 55, CIFAR-10 Batch 5:  loss 0.286881 accuracy 0.6538
# Epoch 56, CIFAR-10 Batch 1:  loss 0.331602 accuracy 0.658
# Epoch 56, CIFAR-10 Batch 2:  loss 0.297645 accuracy 0.6604
# Epoch 56, CIFAR-10 Batch 3:  loss 0.297893 accuracy 0.6492
# Epoch 56, CIFAR-10 Batch 4:  loss 0.312586 accuracy 0.6416
# Epoch 56, CIFAR-10 Batch 5:  loss 0.291947 accuracy 0.6488
# Epoch 57, CIFAR-10 Batch 1:  loss 0.385528 accuracy 0.6318
# Epoch 57, CIFAR-10 Batch 2:  loss 0.32385 accuracy 0.646
# Epoch 57, CIFAR-10 Batch 3:  loss 0.306659 accuracy 0.6456
# Epoch 57, CIFAR-10 Batch 4:  loss 0.30834 accuracy 0.6394
# Epoch 57, CIFAR-10 Batch 5:  loss 0.295625 accuracy 0.645
# Epoch 58, CIFAR-10 Batch 1:  loss 0.384869 accuracy 0.6318
# Epoch 58, CIFAR-10 Batch 2:  loss 0.312564 accuracy 0.6462
# Epoch 58, CIFAR-10 Batch 3:  loss 0.271839 accuracy 0.6544
# Epoch 58, CIFAR-10 Batch 4:  loss 0.264861 accuracy 0.6572
# Epoch 58, CIFAR-10 Batch 5:  loss 0.256742 accuracy 0.656
# Epoch 59, CIFAR-10 Batch 1:  loss 0.311749 accuracy 0.658
# Epoch 59, CIFAR-10 Batch 2:  loss 0.282131 accuracy 0.653
# Epoch 59, CIFAR-10 Batch 3:  loss 0.269214 accuracy 0.6546
# Epoch 59, CIFAR-10 Batch 4:  loss 0.26074 accuracy 0.6574
# Epoch 59, CIFAR-10 Batch 5:  loss 0.249135 accuracy 0.6566
# Epoch 60, CIFAR-10 Batch 1:  loss 0.303868 accuracy 0.6544
# Epoch 60, CIFAR-10 Batch 2:  loss 0.273317 accuracy 0.654
# Epoch 60, CIFAR-10 Batch 3:  loss 0.257823 accuracy 0.652
# Epoch 60, CIFAR-10 Batch 4:  loss 0.252394 accuracy 0.6562
# Epoch 60, CIFAR-10 Batch 5:  loss 0.241438 accuracy 0.659
# Epoch 61, CIFAR-10 Batch 1:  loss 0.306941 accuracy 0.6528
# Epoch 61, CIFAR-10 Batch 2:  loss 0.271935 accuracy 0.6494
# Epoch 61, CIFAR-10 Batch 3:  loss 0.251856 accuracy 0.6528
# Epoch 61, CIFAR-10 Batch 4:  loss 0.247006 accuracy 0.6536
# Epoch 61, CIFAR-10 Batch 5:  loss 0.236505 accuracy 0.6576
# Epoch 62, CIFAR-10 Batch 1:  loss 0.305375 accuracy 0.6516
# Epoch 62, CIFAR-10 Batch 2:  loss 0.269114 accuracy 0.6496
# Epoch 62, CIFAR-10 Batch 3:  loss 0.247297 accuracy 0.6512
# Epoch 62, CIFAR-10 Batch 4:  loss 0.241691 accuracy 0.6536
# Epoch 62, CIFAR-10 Batch 5:  loss 0.231138 accuracy 0.6576
# Epoch 63, CIFAR-10 Batch 1:  loss 0.299348 accuracy 0.6512
# Epoch 63, CIFAR-10 Batch 2:  loss 0.264671 accuracy 0.6526
# Epoch 63, CIFAR-10 Batch 3:  loss 0.24217 accuracy 0.653
# Epoch 63, CIFAR-10 Batch 4:  loss 0.235747 accuracy 0.6556
# Epoch 63, CIFAR-10 Batch 5:  loss 0.225177 accuracy 0.6572
# Epoch 64, CIFAR-10 Batch 1:  loss 0.290188 accuracy 0.6502
# Epoch 64, CIFAR-10 Batch 2:  loss 0.258618 accuracy 0.6542
# Epoch 64, CIFAR-10 Batch 3:  loss 0.237521 accuracy 0.6544
# Epoch 64, CIFAR-10 Batch 4:  loss 0.230102 accuracy 0.6564
# Epoch 64, CIFAR-10 Batch 5:  loss 0.220134 accuracy 0.659
# Epoch 65, CIFAR-10 Batch 1:  loss 0.280669 accuracy 0.6526
# Epoch 65, CIFAR-10 Batch 2:  loss 0.252547 accuracy 0.656
# Epoch 65, CIFAR-10 Batch 3:  loss 0.233993 accuracy 0.654
# Epoch 65, CIFAR-10 Batch 4:  loss 0.225462 accuracy 0.6568
# Epoch 65, CIFAR-10 Batch 5:  loss 0.216648 accuracy 0.6624
# Epoch 66, CIFAR-10 Batch 1:  loss 0.272897 accuracy 0.6542
# Epoch 66, CIFAR-10 Batch 2:  loss 0.247806 accuracy 0.654
# Epoch 66, CIFAR-10 Batch 3:  loss 0.232129 accuracy 0.654
# Epoch 66, CIFAR-10 Batch 4:  loss 0.222356 accuracy 0.657
# Epoch 66, CIFAR-10 Batch 5:  loss 0.215486 accuracy 0.6612
# Epoch 67, CIFAR-10 Batch 1:  loss 0.267371 accuracy 0.6544
# Epoch 67, CIFAR-10 Batch 2:  loss 0.245027 accuracy 0.6522
# Epoch 67, CIFAR-10 Batch 3:  loss 0.232843 accuracy 0.6538
# Epoch 67, CIFAR-10 Batch 4:  loss 0.222812 accuracy 0.6534
# Epoch 67, CIFAR-10 Batch 5:  loss 0.220191 accuracy 0.656
# Epoch 68, CIFAR-10 Batch 1:  loss 0.268409 accuracy 0.6562
# Epoch 68, CIFAR-10 Batch 2:  loss 0.249633 accuracy 0.6478
# Epoch 68, CIFAR-10 Batch 3:  loss 0.243769 accuracy 0.6486
# Epoch 68, CIFAR-10 Batch 4:  loss 0.237009 accuracy 0.645
# Epoch 68, CIFAR-10 Batch 5:  loss 0.250135 accuracy 0.6408
# Epoch 69, CIFAR-10 Batch 1:  loss 0.302526 accuracy 0.6482
# Epoch 69, CIFAR-10 Batch 2:  loss 0.296887 accuracy 0.6304
# Epoch 69, CIFAR-10 Batch 3:  loss 0.329204 accuracy 0.6222
# Epoch 69, CIFAR-10 Batch 4:  loss 0.318442 accuracy 0.6194
# Epoch 69, CIFAR-10 Batch 5:  loss 0.342571 accuracy 0.6126
# Epoch 70, CIFAR-10 Batch 1:  loss 0.380427 accuracy 0.6172
# Epoch 70, CIFAR-10 Batch 2:  loss 0.289925 accuracy 0.639
# Epoch 70, CIFAR-10 Batch 3:  loss 0.236987 accuracy 0.6552
# Epoch 70, CIFAR-10 Batch 4:  loss 0.29727 accuracy 0.6266
# Epoch 70, CIFAR-10 Batch 5:  loss 0.248095 accuracy 0.6482
# Epoch 71, CIFAR-10 Batch 1:  loss 0.290106 accuracy 0.6398
# Epoch 71, CIFAR-10 Batch 2:  loss 0.264649 accuracy 0.6434
# Epoch 71, CIFAR-10 Batch 3:  loss 0.308474 accuracy 0.6268
# Epoch 71, CIFAR-10 Batch 4:  loss 0.32128 accuracy 0.6176
# Epoch 71, CIFAR-10 Batch 5:  loss 0.337832 accuracy 0.617
# Epoch 72, CIFAR-10 Batch 1:  loss 0.356401 accuracy 0.6158
# Epoch 72, CIFAR-10 Batch 2:  loss 0.250471 accuracy 0.6504
# Epoch 72, CIFAR-10 Batch 3:  loss 0.257319 accuracy 0.642
# Epoch 72, CIFAR-10 Batch 4:  loss 0.226118 accuracy 0.647
# Epoch 72, CIFAR-10 Batch 5:  loss 0.250656 accuracy 0.6398
# Epoch 73, CIFAR-10 Batch 1:  loss 0.269362 accuracy 0.6468
# Epoch 73, CIFAR-10 Batch 2:  loss 0.292533 accuracy 0.6392
# Epoch 73, CIFAR-10 Batch 3:  loss 0.252842 accuracy 0.6432
# Epoch 73, CIFAR-10 Batch 4:  loss 0.239718 accuracy 0.6468
# Epoch 73, CIFAR-10 Batch 5:  loss 0.225266 accuracy 0.652
# Epoch 74, CIFAR-10 Batch 1:  loss 0.247447 accuracy 0.6548
# Epoch 74, CIFAR-10 Batch 2:  loss 0.266793 accuracy 0.6434
# Epoch 74, CIFAR-10 Batch 3:  loss 0.23761 accuracy 0.649
# Epoch 74, CIFAR-10 Batch 4:  loss 0.236308 accuracy 0.6464
# Epoch 74, CIFAR-10 Batch 5:  loss 0.223532 accuracy 0.6508
# Epoch 75, CIFAR-10 Batch 1:  loss 0.238937 accuracy 0.6562
# Epoch 75, CIFAR-10 Batch 2:  loss 0.260265 accuracy 0.6444
# Epoch 75, CIFAR-10 Batch 3:  loss 0.226 accuracy 0.6482
# Epoch 75, CIFAR-10 Batch 4:  loss 0.231884 accuracy 0.6402
# Epoch 75, CIFAR-10 Batch 5:  loss 0.224171 accuracy 0.6476
# Epoch 76, CIFAR-10 Batch 1:  loss 0.239619 accuracy 0.6546
# Epoch 76, CIFAR-10 Batch 2:  loss 0.262639 accuracy 0.6416
# Epoch 76, CIFAR-10 Batch 3:  loss 0.217783 accuracy 0.6496
# Epoch 76, CIFAR-10 Batch 4:  loss 0.235744 accuracy 0.6364
# Epoch 76, CIFAR-10 Batch 5:  loss 0.21909 accuracy 0.6472
# Epoch 77, CIFAR-10 Batch 1:  loss 0.242346 accuracy 0.6526
# Epoch 77, CIFAR-10 Batch 2:  loss 0.262692 accuracy 0.644
# Epoch 77, CIFAR-10 Batch 3:  loss 0.208852 accuracy 0.6484
# Epoch 77, CIFAR-10 Batch 4:  loss 0.248092 accuracy 0.6284
# Epoch 77, CIFAR-10 Batch 5:  loss 0.201714 accuracy 0.6512
# Epoch 78, CIFAR-10 Batch 1:  loss 0.267761 accuracy 0.647
# Epoch 78, CIFAR-10 Batch 2:  loss 0.240958 accuracy 0.6498
# Epoch 78, CIFAR-10 Batch 3:  loss 0.206911 accuracy 0.6462
# Epoch 78, CIFAR-10 Batch 4:  loss 0.241704 accuracy 0.6298
# Epoch 78, CIFAR-10 Batch 5:  loss 0.198445 accuracy 0.6508
# Epoch 79, CIFAR-10 Batch 1:  loss 0.284383 accuracy 0.6378
# Epoch 79, CIFAR-10 Batch 2:  loss 0.21222 accuracy 0.6536
# Epoch 79, CIFAR-10 Batch 3:  loss 0.211529 accuracy 0.644
# Epoch 79, CIFAR-10 Batch 4:  loss 0.203446 accuracy 0.6464
# Epoch 79, CIFAR-10 Batch 5:  loss 0.215386 accuracy 0.639
# Epoch 80, CIFAR-10 Batch 1:  loss 0.241394 accuracy 0.649
# Epoch 80, CIFAR-10 Batch 2:  loss 0.217273 accuracy 0.647
# Epoch 80, CIFAR-10 Batch 3:  loss 0.189552 accuracy 0.6548
# Epoch 80, CIFAR-10 Batch 4:  loss 0.204363 accuracy 0.6494
# Epoch 80, CIFAR-10 Batch 5:  loss 0.187821 accuracy 0.6498
# Epoch 81, CIFAR-10 Batch 1:  loss 0.228928 accuracy 0.6504
# Epoch 81, CIFAR-10 Batch 2:  loss 0.213657 accuracy 0.6474
# Epoch 81, CIFAR-10 Batch 3:  loss 0.181245 accuracy 0.6594
# Epoch 81, CIFAR-10 Batch 4:  loss 0.206528 accuracy 0.649
# Epoch 81, CIFAR-10 Batch 5:  loss 0.172168 accuracy 0.6538
# Epoch 82, CIFAR-10 Batch 1:  loss 0.227442 accuracy 0.6478
# Epoch 82, CIFAR-10 Batch 2:  loss 0.203894 accuracy 0.6514
# Epoch 82, CIFAR-10 Batch 3:  loss 0.178166 accuracy 0.6578
# Epoch 82, CIFAR-10 Batch 4:  loss 0.200704 accuracy 0.6502
# Epoch 82, CIFAR-10 Batch 5:  loss 0.167713 accuracy 0.655
# Epoch 83, CIFAR-10 Batch 1:  loss 0.223708 accuracy 0.6506
# Epoch 83, CIFAR-10 Batch 2:  loss 0.196539 accuracy 0.6538
# Epoch 83, CIFAR-10 Batch 3:  loss 0.17485 accuracy 0.6576
# Epoch 83, CIFAR-10 Batch 4:  loss 0.195211 accuracy 0.651
# Epoch 83, CIFAR-10 Batch 5:  loss 0.165024 accuracy 0.6536
# Epoch 84, CIFAR-10 Batch 1:  loss 0.219335 accuracy 0.6508
# Epoch 84, CIFAR-10 Batch 2:  loss 0.192108 accuracy 0.6538
# Epoch 84, CIFAR-10 Batch 3:  loss 0.171367 accuracy 0.657
# Epoch 84, CIFAR-10 Batch 4:  loss 0.191384 accuracy 0.6502
# Epoch 84, CIFAR-10 Batch 5:  loss 0.162357 accuracy 0.653
# Epoch 85, CIFAR-10 Batch 1:  loss 0.215328 accuracy 0.6498
# Epoch 85, CIFAR-10 Batch 2:  loss 0.189367 accuracy 0.6536
# Epoch 85, CIFAR-10 Batch 3:  loss 0.168266 accuracy 0.6576
# Epoch 85, CIFAR-10 Batch 4:  loss 0.188558 accuracy 0.6488
# Epoch 85, CIFAR-10 Batch 5:  loss 0.159829 accuracy 0.6538
# Epoch 86, CIFAR-10 Batch 1:  loss 0.2114 accuracy 0.651
# Epoch 86, CIFAR-10 Batch 2:  loss 0.187258 accuracy 0.6552
# Epoch 86, CIFAR-10 Batch 3:  loss 0.165929 accuracy 0.6592
# Epoch 86, CIFAR-10 Batch 4:  loss 0.18638 accuracy 0.6476
# Epoch 86, CIFAR-10 Batch 5:  loss 0.157327 accuracy 0.6528
# Epoch 87, CIFAR-10 Batch 1:  loss 0.20757 accuracy 0.6502
# Epoch 87, CIFAR-10 Batch 2:  loss 0.185357 accuracy 0.6542
# Epoch 87, CIFAR-10 Batch 3:  loss 0.164622 accuracy 0.6602
# Epoch 87, CIFAR-10 Batch 4:  loss 0.18484 accuracy 0.647
# Epoch 87, CIFAR-10 Batch 5:  loss 0.154707 accuracy 0.6542
# Epoch 88, CIFAR-10 Batch 1:  loss 0.203835 accuracy 0.651
# Epoch 88, CIFAR-10 Batch 2:  loss 0.18427 accuracy 0.6546
# Epoch 88, CIFAR-10 Batch 3:  loss 0.165183 accuracy 0.6572
# Epoch 88, CIFAR-10 Batch 4:  loss 0.184822 accuracy 0.6466
# Epoch 88, CIFAR-10 Batch 5:  loss 0.15273 accuracy 0.6546
# Epoch 89, CIFAR-10 Batch 1:  loss 0.201483 accuracy 0.652
# Epoch 89, CIFAR-10 Batch 2:  loss 0.186634 accuracy 0.6522
# Epoch 89, CIFAR-10 Batch 3:  loss 0.171256 accuracy 0.6532
# Epoch 89, CIFAR-10 Batch 4:  loss 0.190653 accuracy 0.6434
# Epoch 89, CIFAR-10 Batch 5:  loss 0.155209 accuracy 0.6534
# Epoch 90, CIFAR-10 Batch 1:  loss 0.206951 accuracy 0.6514
# Epoch 90, CIFAR-10 Batch 2:  loss 0.203038 accuracy 0.6484
# Epoch 90, CIFAR-10 Batch 3:  loss 0.196228 accuracy 0.6466
# Epoch 90, CIFAR-10 Batch 4:  loss 0.21302 accuracy 0.6378
# Epoch 90, CIFAR-10 Batch 5:  loss 0.168259 accuracy 0.6474
# Epoch 91, CIFAR-10 Batch 1:  loss 0.214106 accuracy 0.6488
# Epoch 91, CIFAR-10 Batch 2:  loss 0.191404 accuracy 0.6482
# Epoch 91, CIFAR-10 Batch 3:  loss 0.176981 accuracy 0.652
# Epoch 91, CIFAR-10 Batch 4:  loss 0.182909 accuracy 0.6486
# Epoch 91, CIFAR-10 Batch 5:  loss 0.139273 accuracy 0.6554
# Epoch 92, CIFAR-10 Batch 1:  loss 0.180366 accuracy 0.6546
# Epoch 92, CIFAR-10 Batch 2:  loss 0.162017 accuracy 0.6562
# Epoch 92, CIFAR-10 Batch 3:  loss 0.156539 accuracy 0.6604
# Epoch 92, CIFAR-10 Batch 4:  loss 0.16757 accuracy 0.6474
# Epoch 92, CIFAR-10 Batch 5:  loss 0.148512 accuracy 0.6514
# Epoch 93, CIFAR-10 Batch 1:  loss 0.183323 accuracy 0.6548
# Epoch 93, CIFAR-10 Batch 2:  loss 0.157865 accuracy 0.6578
# Epoch 93, CIFAR-10 Batch 3:  loss 0.149108 accuracy 0.6592
# Epoch 93, CIFAR-10 Batch 4:  loss 0.161142 accuracy 0.6478
# Epoch 93, CIFAR-10 Batch 5:  loss 0.150654 accuracy 0.6494
# Epoch 94, CIFAR-10 Batch 1:  loss 0.18555 accuracy 0.6498
# Epoch 94, CIFAR-10 Batch 2:  loss 0.15335 accuracy 0.6612
# Epoch 94, CIFAR-10 Batch 3:  loss 0.141672 accuracy 0.658
# Epoch 94, CIFAR-10 Batch 4:  loss 0.159775 accuracy 0.6464
# Epoch 94, CIFAR-10 Batch 5:  loss 0.154345 accuracy 0.6422
# Epoch 95, CIFAR-10 Batch 1:  loss 0.194118 accuracy 0.643
# Epoch 95, CIFAR-10 Batch 2:  loss 0.155846 accuracy 0.6558
# Epoch 95, CIFAR-10 Batch 3:  loss 0.141138 accuracy 0.6586
# Epoch 95, CIFAR-10 Batch 4:  loss 0.166795 accuracy 0.6426
# Epoch 95, CIFAR-10 Batch 5:  loss 0.173399 accuracy 0.633
# Epoch 96, CIFAR-10 Batch 1:  loss 0.214524 accuracy 0.6368
# Epoch 96, CIFAR-10 Batch 2:  loss 0.165879 accuracy 0.6522
# Epoch 96, CIFAR-10 Batch 3:  loss 0.147517 accuracy 0.6526
# Epoch 96, CIFAR-10 Batch 4:  loss 0.184144 accuracy 0.6346
# Epoch 96, CIFAR-10 Batch 5:  loss 0.199691 accuracy 0.6238
# Epoch 97, CIFAR-10 Batch 1:  loss 0.21605 accuracy 0.6362
# Epoch 97, CIFAR-10 Batch 2:  loss 0.15789 accuracy 0.6546
# Epoch 97, CIFAR-10 Batch 3:  loss 0.139129 accuracy 0.6566
# Epoch 97, CIFAR-10 Batch 4:  loss 0.156279 accuracy 0.642
# Epoch 97, CIFAR-10 Batch 5:  loss 0.152521 accuracy 0.6382
# Epoch 98, CIFAR-10 Batch 1:  loss 0.167821 accuracy 0.65
# Epoch 98, CIFAR-10 Batch 2:  loss 0.14413 accuracy 0.6582
# Epoch 98, CIFAR-10 Batch 3:  loss 0.142144 accuracy 0.657
# Epoch 98, CIFAR-10 Batch 4:  loss 0.137027 accuracy 0.6476
# Epoch 98, CIFAR-10 Batch 5:  loss 0.134891 accuracy 0.6468
# Epoch 99, CIFAR-10 Batch 1:  loss 0.154682 accuracy 0.659
# Epoch 99, CIFAR-10 Batch 2:  loss 0.151624 accuracy 0.6576
# Epoch 99, CIFAR-10 Batch 3:  loss 0.151613 accuracy 0.656
# Epoch 99, CIFAR-10 Batch 4:  loss 0.13534 accuracy 0.6488
# Epoch 99, CIFAR-10 Batch 5:  loss 0.135787 accuracy 0.6438
# Epoch 100, CIFAR-10 Batch 1:  loss 0.151861 accuracy 0.6592
# Epoch 100, CIFAR-10 Batch 2:  loss 0.153039 accuracy 0.6552
# Epoch 100, CIFAR-10 Batch 3:  loss 0.149869 accuracy 0.654
# Epoch 100, CIFAR-10 Batch 4:  loss 0.13093 accuracy 0.6494
# Epoch 100, CIFAR-10 Batch 5:  loss 0.134071 accuracy 0.6436
# Epoch 101, CIFAR-10 Batch 1:  loss 0.14705 accuracy 0.6582
# Epoch 101, CIFAR-10 Batch 2:  loss 0.145025 accuracy 0.6564
# Epoch 101, CIFAR-10 Batch 3:  loss 0.139086 accuracy 0.6532
# Epoch 101, CIFAR-10 Batch 4:  loss 0.125591 accuracy 0.651
# Epoch 101, CIFAR-10 Batch 5:  loss 0.131728 accuracy 0.6416
# Epoch 102, CIFAR-10 Batch 1:  loss 0.145134 accuracy 0.6576
# Epoch 102, CIFAR-10 Batch 2:  loss 0.136039 accuracy 0.658
# Epoch 102, CIFAR-10 Batch 3:  loss 0.128817 accuracy 0.6556
# Epoch 102, CIFAR-10 Batch 4:  loss 0.126099 accuracy 0.6494
# Epoch 102, CIFAR-10 Batch 5:  loss 0.135891 accuracy 0.6378
# Epoch 103, CIFAR-10 Batch 1:  loss 0.152876 accuracy 0.6494
# Epoch 103, CIFAR-10 Batch 2:  loss 0.133938 accuracy 0.6584
# Epoch 103, CIFAR-10 Batch 3:  loss 0.124701 accuracy 0.6554
# Epoch 103, CIFAR-10 Batch 4:  loss 0.136163 accuracy 0.6436
# Epoch 103, CIFAR-10 Batch 5:  loss 0.153635 accuracy 0.6318
# Epoch 104, CIFAR-10 Batch 1:  loss 0.17464 accuracy 0.6392
# Epoch 104, CIFAR-10 Batch 2:  loss 0.144301 accuracy 0.6552
# Epoch 104, CIFAR-10 Batch 3:  loss 0.130935 accuracy 0.6504
# Epoch 104, CIFAR-10 Batch 4:  loss 0.159539 accuracy 0.629
# Epoch 104, CIFAR-10 Batch 5:  loss 0.191638 accuracy 0.6206
# Epoch 105, CIFAR-10 Batch 1:  loss 0.20929 accuracy 0.6292
# Epoch 105, CIFAR-10 Batch 2:  loss 0.166208 accuracy 0.6486
# Epoch 105, CIFAR-10 Batch 3:  loss 0.133025 accuracy 0.6492
# Epoch 105, CIFAR-10 Batch 4:  loss 0.162987 accuracy 0.6272
# Epoch 105, CIFAR-10 Batch 5:  loss 0.183977 accuracy 0.6202
# Epoch 106, CIFAR-10 Batch 1:  loss 0.160882 accuracy 0.6462
# Epoch 106, CIFAR-10 Batch 2:  loss 0.156801 accuracy 0.6528
# Epoch 106, CIFAR-10 Batch 3:  loss 0.14491 accuracy 0.649
# Epoch 106, CIFAR-10 Batch 4:  loss 0.140223 accuracy 0.6424
# Epoch 106, CIFAR-10 Batch 5:  loss 0.154567 accuracy 0.6336
# Epoch 107, CIFAR-10 Batch 1:  loss 0.164139 accuracy 0.6506
# Epoch 107, CIFAR-10 Batch 2:  loss 0.167219 accuracy 0.6416
# Epoch 107, CIFAR-10 Batch 3:  loss 0.154045 accuracy 0.6458
# Epoch 107, CIFAR-10 Batch 4:  loss 0.129872 accuracy 0.6408
# Epoch 107, CIFAR-10 Batch 5:  loss 0.120881 accuracy 0.647
# Epoch 108, CIFAR-10 Batch 1:  loss 0.178964 accuracy 0.6462
# Epoch 108, CIFAR-10 Batch 2:  loss 0.12912 accuracy 0.6572
# Epoch 108, CIFAR-10 Batch 3:  loss 0.15099 accuracy 0.643
# Epoch 108, CIFAR-10 Batch 4:  loss 0.133081 accuracy 0.641
# Epoch 108, CIFAR-10 Batch 5:  loss 0.134877 accuracy 0.6448
# Epoch 109, CIFAR-10 Batch 1:  loss 0.179262 accuracy 0.6418
# Epoch 109, CIFAR-10 Batch 2:  loss 0.131026 accuracy 0.6494
# Epoch 109, CIFAR-10 Batch 3:  loss 0.163797 accuracy 0.6416
# Epoch 109, CIFAR-10 Batch 4:  loss 0.122201 accuracy 0.6454
# Epoch 109, CIFAR-10 Batch 5:  loss 0.141901 accuracy 0.6444
# Epoch 110, CIFAR-10 Batch 1:  loss 0.142672 accuracy 0.6538
# Epoch 110, CIFAR-10 Batch 2:  loss 0.161513 accuracy 0.6306
# Epoch 110, CIFAR-10 Batch 3:  loss 0.15593 accuracy 0.6396
# Epoch 110, CIFAR-10 Batch 4:  loss 0.127281 accuracy 0.6452
# Epoch 110, CIFAR-10 Batch 5:  loss 0.144074 accuracy 0.6368
# Epoch 111, CIFAR-10 Batch 1:  loss 0.133892 accuracy 0.6578
# Epoch 111, CIFAR-10 Batch 2:  loss 0.150885 accuracy 0.6328
# Epoch 111, CIFAR-10 Batch 3:  loss 0.140372 accuracy 0.6468
# Epoch 111, CIFAR-10 Batch 4:  loss 0.124832 accuracy 0.646
# Epoch 111, CIFAR-10 Batch 5:  loss 0.148375 accuracy 0.6318
# Epoch 112, CIFAR-10 Batch 1:  loss 0.1276 accuracy 0.658
# Epoch 112, CIFAR-10 Batch 2:  loss 0.145755 accuracy 0.6392
# Epoch 112, CIFAR-10 Batch 3:  loss 0.122733 accuracy 0.6524
# Epoch 112, CIFAR-10 Batch 4:  loss 0.12301 accuracy 0.6428
# Epoch 112, CIFAR-10 Batch 5:  loss 0.140969 accuracy 0.6314
# Epoch 113, CIFAR-10 Batch 1:  loss 0.126479 accuracy 0.6574
# Epoch 113, CIFAR-10 Batch 2:  loss 0.157565 accuracy 0.6354
# Epoch 113, CIFAR-10 Batch 3:  loss 0.115434 accuracy 0.6548
# Epoch 113, CIFAR-10 Batch 4:  loss 0.143053 accuracy 0.6324
# Epoch 113, CIFAR-10 Batch 5:  loss 0.12634 accuracy 0.6376
# Epoch 114, CIFAR-10 Batch 1:  loss 0.140639 accuracy 0.6544
# Epoch 114, CIFAR-10 Batch 2:  loss 0.184709 accuracy 0.6232
# Epoch 114, CIFAR-10 Batch 3:  loss 0.144066 accuracy 0.644
# Epoch 114, CIFAR-10 Batch 4:  loss 0.18256 accuracy 0.6208
# Epoch 114, CIFAR-10 Batch 5:  loss 0.111046 accuracy 0.6502
# Epoch 115, CIFAR-10 Batch 1:  loss 0.19807 accuracy 0.6424
# Epoch 115, CIFAR-10 Batch 2:  loss 0.176573 accuracy 0.6272
# Epoch 115, CIFAR-10 Batch 3:  loss 0.195856 accuracy 0.6238
# Epoch 115, CIFAR-10 Batch 4:  loss 0.160864 accuracy 0.6274
# Epoch 115, CIFAR-10 Batch 5:  loss 0.14004 accuracy 0.6454
# Epoch 116, CIFAR-10 Batch 1:  loss 0.14018 accuracy 0.6526
# Epoch 116, CIFAR-10 Batch 2:  loss 0.140529 accuracy 0.6488
# Epoch 116, CIFAR-10 Batch 3:  loss 0.149194 accuracy 0.6306
# Epoch 116, CIFAR-10 Batch 4:  loss 0.161638 accuracy 0.6198
# Epoch 116, CIFAR-10 Batch 5:  loss 0.171541 accuracy 0.6244
# Epoch 117, CIFAR-10 Batch 1:  loss 0.142059 accuracy 0.6458
# Epoch 117, CIFAR-10 Batch 2:  loss 0.131158 accuracy 0.6492
# Epoch 117, CIFAR-10 Batch 3:  loss 0.139533 accuracy 0.6364
# Epoch 117, CIFAR-10 Batch 4:  loss 0.148368 accuracy 0.6362
# Epoch 117, CIFAR-10 Batch 5:  loss 0.189725 accuracy 0.6202
# Epoch 118, CIFAR-10 Batch 1:  loss 0.160176 accuracy 0.638
# Epoch 118, CIFAR-10 Batch 2:  loss 0.162087 accuracy 0.63
# Epoch 118, CIFAR-10 Batch 3:  loss 0.108035 accuracy 0.652
# Epoch 118, CIFAR-10 Batch 4:  loss 0.161416 accuracy 0.6308
# Epoch 118, CIFAR-10 Batch 5:  loss 0.127219 accuracy 0.6414
# Epoch 119, CIFAR-10 Batch 1:  loss 0.245509 accuracy 0.6114
# Epoch 119, CIFAR-10 Batch 2:  loss 0.20344 accuracy 0.6186
# Epoch 119, CIFAR-10 Batch 3:  loss 0.141175 accuracy 0.6514
# Epoch 119, CIFAR-10 Batch 4:  loss 0.186961 accuracy 0.6258
# Epoch 119, CIFAR-10 Batch 5:  loss 0.121226 accuracy 0.6466
# Epoch 120, CIFAR-10 Batch 1:  loss 0.211396 accuracy 0.6328
# Epoch 120, CIFAR-10 Batch 2:  loss 0.184504 accuracy 0.629
# Epoch 120, CIFAR-10 Batch 3:  loss 0.23698 accuracy 0.617
# Epoch 120, CIFAR-10 Batch 4:  loss 0.175534 accuracy 0.6396
# Epoch 120, CIFAR-10 Batch 5:  loss 0.190539 accuracy 0.6268
# Epoch 121, CIFAR-10 Batch 1:  loss 0.172118 accuracy 0.6424
# Epoch 121, CIFAR-10 Batch 2:  loss 0.189776 accuracy 0.6232
# Epoch 121, CIFAR-10 Batch 3:  loss 0.160129 accuracy 0.6438
# Epoch 121, CIFAR-10 Batch 4:  loss 0.145746 accuracy 0.641
# Epoch 121, CIFAR-10 Batch 5:  loss 0.120612 accuracy 0.6522
# Epoch 122, CIFAR-10 Batch 1:  loss 0.179636 accuracy 0.6344
# Epoch 122, CIFAR-10 Batch 2:  loss 0.187619 accuracy 0.623
# Epoch 122, CIFAR-10 Batch 3:  loss 0.200175 accuracy 0.6342
# Epoch 122, CIFAR-10 Batch 4:  loss 0.145511 accuracy 0.639
# Epoch 122, CIFAR-10 Batch 5:  loss 0.135928 accuracy 0.6438
# Epoch 123, CIFAR-10 Batch 1:  loss 0.152043 accuracy 0.6416
# Epoch 123, CIFAR-10 Batch 2:  loss 0.212372 accuracy 0.6166
# Epoch 123, CIFAR-10 Batch 3:  loss 0.230887 accuracy 0.627
# Epoch 123, CIFAR-10 Batch 4:  loss 0.172526 accuracy 0.6388
# Epoch 123, CIFAR-10 Batch 5:  loss 0.133026 accuracy 0.6454
# Epoch 124, CIFAR-10 Batch 1:  loss 0.142998 accuracy 0.6454
# Epoch 124, CIFAR-10 Batch 2:  loss 0.174208 accuracy 0.6278
# Epoch 124, CIFAR-10 Batch 3:  loss 0.18946 accuracy 0.629
# Epoch 124, CIFAR-10 Batch 4:  loss 0.213259 accuracy 0.6248
# Epoch 124, CIFAR-10 Batch 5:  loss 0.196047 accuracy 0.6294
# Epoch 125, CIFAR-10 Batch 1:  loss 0.195133 accuracy 0.638
# Epoch 125, CIFAR-10 Batch 2:  loss 0.130462 accuracy 0.6536
# Epoch 125, CIFAR-10 Batch 3:  loss 0.135908 accuracy 0.6412
# Epoch 125, CIFAR-10 Batch 4:  loss 0.156418 accuracy 0.638
# Epoch 125, CIFAR-10 Batch 5:  loss 0.160438 accuracy 0.6364
# Epoch 126, CIFAR-10 Batch 1:  loss 0.180143 accuracy 0.641
# Epoch 126, CIFAR-10 Batch 2:  loss 0.154645 accuracy 0.6496
# Epoch 126, CIFAR-10 Batch 3:  loss 0.137684 accuracy 0.6406
# Epoch 126, CIFAR-10 Batch 4:  loss 0.128769 accuracy 0.6518
# Epoch 126, CIFAR-10 Batch 5:  loss 0.108008 accuracy 0.649
# Epoch 127, CIFAR-10 Batch 1:  loss 0.116005 accuracy 0.655
# Epoch 127, CIFAR-10 Batch 2:  loss 0.121922 accuracy 0.6516
# Epoch 127, CIFAR-10 Batch 3:  loss 0.121449 accuracy 0.644
# Epoch 127, CIFAR-10 Batch 4:  loss 0.124032 accuracy 0.6512
# Epoch 127, CIFAR-10 Batch 5:  loss 0.105112 accuracy 0.6458
# Epoch 128, CIFAR-10 Batch 1:  loss 0.107208 accuracy 0.6548
# Epoch 128, CIFAR-10 Batch 2:  loss 0.11641 accuracy 0.6518
# Epoch 128, CIFAR-10 Batch 3:  loss 0.121676 accuracy 0.6416
# Epoch 128, CIFAR-10 Batch 4:  loss 0.119904 accuracy 0.6476
# Epoch 128, CIFAR-10 Batch 5:  loss 0.1078 accuracy 0.6444
# Epoch 129, CIFAR-10 Batch 1:  loss 0.106543 accuracy 0.6554
# Epoch 129, CIFAR-10 Batch 2:  loss 0.111474 accuracy 0.652
# Epoch 129, CIFAR-10 Batch 3:  loss 0.120079 accuracy 0.6406
# Epoch 129, CIFAR-10 Batch 4:  loss 0.119329 accuracy 0.643
# Epoch 129, CIFAR-10 Batch 5:  loss 0.110466 accuracy 0.643
# Epoch 130, CIFAR-10 Batch 1:  loss 0.106179 accuracy 0.6554
# Epoch 130, CIFAR-10 Batch 2:  loss 0.106065 accuracy 0.6506
# Epoch 130, CIFAR-10 Batch 3:  loss 0.117095 accuracy 0.6418
# Epoch 130, CIFAR-10 Batch 4:  loss 0.119826 accuracy 0.6422
# Epoch 130, CIFAR-10 Batch 5:  loss 0.112617 accuracy 0.6424
# Epoch 131, CIFAR-10 Batch 1:  loss 0.106012 accuracy 0.6568
# Epoch 131, CIFAR-10 Batch 2:  loss 0.101356 accuracy 0.6522
# Epoch 131, CIFAR-10 Batch 3:  loss 0.112314 accuracy 0.6436
# Epoch 131, CIFAR-10 Batch 4:  loss 0.119419 accuracy 0.6424
# Epoch 131, CIFAR-10 Batch 5:  loss 0.115292 accuracy 0.6392
# Epoch 132, CIFAR-10 Batch 1:  loss 0.10707 accuracy 0.6554
# Epoch 132, CIFAR-10 Batch 2:  loss 0.0976116 accuracy 0.6528
# Epoch 132, CIFAR-10 Batch 3:  loss 0.106739 accuracy 0.6436
# Epoch 132, CIFAR-10 Batch 4:  loss 0.117353 accuracy 0.6422
# Epoch 132, CIFAR-10 Batch 5:  loss 0.118864 accuracy 0.635
# Epoch 133, CIFAR-10 Batch 1:  loss 0.110093 accuracy 0.6558
# Epoch 133, CIFAR-10 Batch 2:  loss 0.0949931 accuracy 0.6522
# Epoch 133, CIFAR-10 Batch 3:  loss 0.101453 accuracy 0.6476
# Epoch 133, CIFAR-10 Batch 4:  loss 0.113349 accuracy 0.6414
# Epoch 133, CIFAR-10 Batch 5:  loss 0.12276 accuracy 0.632
# Epoch 134, CIFAR-10 Batch 1:  loss 0.114887 accuracy 0.65
# Epoch 134, CIFAR-10 Batch 2:  loss 0.0940283 accuracy 0.6502
# Epoch 134, CIFAR-10 Batch 3:  loss 0.0971295 accuracy 0.6508
# Epoch 134, CIFAR-10 Batch 4:  loss 0.107484 accuracy 0.6442
# Epoch 134, CIFAR-10 Batch 5:  loss 0.125086 accuracy 0.628
# Epoch 135, CIFAR-10 Batch 1:  loss 0.121427 accuracy 0.6442
# Epoch 135, CIFAR-10 Batch 2:  loss 0.0954838 accuracy 0.6462
# Epoch 135, CIFAR-10 Batch 3:  loss 0.0942687 accuracy 0.6538
# Epoch 135, CIFAR-10 Batch 4:  loss 0.100057 accuracy 0.6484
# Epoch 135, CIFAR-10 Batch 5:  loss 0.122978 accuracy 0.6278
# Epoch 136, CIFAR-10 Batch 1:  loss 0.12849 accuracy 0.6392
# Epoch 136, CIFAR-10 Batch 2:  loss 0.100706 accuracy 0.6474
# Epoch 136, CIFAR-10 Batch 3:  loss 0.093478 accuracy 0.6552
# Epoch 136, CIFAR-10 Batch 4:  loss 0.0923905 accuracy 0.6526
# Epoch 136, CIFAR-10 Batch 5:  loss 0.114813 accuracy 0.6304
# Epoch 137, CIFAR-10 Batch 1:  loss 0.132986 accuracy 0.6358
# Epoch 137, CIFAR-10 Batch 2:  loss 0.110917 accuracy 0.6412
# Epoch 137, CIFAR-10 Batch 3:  loss 0.0961593 accuracy 0.6536
# Epoch 137, CIFAR-10 Batch 4:  loss 0.0866022 accuracy 0.6552
# Epoch 137, CIFAR-10 Batch 5:  loss 0.102499 accuracy 0.6366
# Epoch 138, CIFAR-10 Batch 1:  loss 0.129167 accuracy 0.6362
# Epoch 138, CIFAR-10 Batch 2:  loss 0.123917 accuracy 0.6334
# Epoch 138, CIFAR-10 Batch 3:  loss 0.106339 accuracy 0.6464
# Epoch 138, CIFAR-10 Batch 4:  loss 0.0858255 accuracy 0.6546
# Epoch 138, CIFAR-10 Batch 5:  loss 0.0906695 accuracy 0.6408
# Epoch 139, CIFAR-10 Batch 1:  loss 0.116185 accuracy 0.6386
# Epoch 139, CIFAR-10 Batch 2:  loss 0.129954 accuracy 0.6296
# Epoch 139, CIFAR-10 Batch 3:  loss 0.126284 accuracy 0.6398
# Epoch 139, CIFAR-10 Batch 4:  loss 0.0949674 accuracy 0.652
# Epoch 139, CIFAR-10 Batch 5:  loss 0.0855737 accuracy 0.6432
# Epoch 140, CIFAR-10 Batch 1:  loss 0.101541 accuracy 0.6488
# Epoch 140, CIFAR-10 Batch 2:  loss 0.116554 accuracy 0.633
# Epoch 140, CIFAR-10 Batch 3:  loss 0.121869 accuracy 0.641
# Epoch 140, CIFAR-10 Batch 4:  loss 0.110383 accuracy 0.642
# Epoch 140, CIFAR-10 Batch 5:  loss 0.0929414 accuracy 0.6406
# Epoch 141, CIFAR-10 Batch 1:  loss 0.0956583 accuracy 0.6526
# Epoch 141, CIFAR-10 Batch 2:  loss 0.0986467 accuracy 0.6386
# Epoch 141, CIFAR-10 Batch 3:  loss 0.0915299 accuracy 0.6514
# Epoch 141, CIFAR-10 Batch 4:  loss 0.103963 accuracy 0.6428
# Epoch 141, CIFAR-10 Batch 5:  loss 0.0959127 accuracy 0.6338
# Epoch 142, CIFAR-10 Batch 1:  loss 0.0971024 accuracy 0.6496
# Epoch 142, CIFAR-10 Batch 2:  loss 0.0898147 accuracy 0.6434
# Epoch 142, CIFAR-10 Batch 3:  loss 0.0790959 accuracy 0.6602
# Epoch 142, CIFAR-10 Batch 4:  loss 0.0885527 accuracy 0.6508
# Epoch 142, CIFAR-10 Batch 5:  loss 0.0860528 accuracy 0.6376
# Epoch 143, CIFAR-10 Batch 1:  loss 0.0969046 accuracy 0.6446
# Epoch 143, CIFAR-10 Batch 2:  loss 0.0853933 accuracy 0.6432
# Epoch 143, CIFAR-10 Batch 3:  loss 0.0751561 accuracy 0.66
# Epoch 143, CIFAR-10 Batch 4:  loss 0.0822657 accuracy 0.653
# Epoch 143, CIFAR-10 Batch 5:  loss 0.0789664 accuracy 0.637
# Epoch 144, CIFAR-10 Batch 1:  loss 0.0944851 accuracy 0.6474
# Epoch 144, CIFAR-10 Batch 2:  loss 0.0826133 accuracy 0.6436
# Epoch 144, CIFAR-10 Batch 3:  loss 0.0727159 accuracy 0.6602
# Epoch 144, CIFAR-10 Batch 4:  loss 0.0793972 accuracy 0.655
# Epoch 144, CIFAR-10 Batch 5:  loss 0.0753763 accuracy 0.635
# Epoch 145, CIFAR-10 Batch 1:  loss 0.0924292 accuracy 0.6462
# Epoch 145, CIFAR-10 Batch 2:  loss 0.0802308 accuracy 0.6416
# Epoch 145, CIFAR-10 Batch 3:  loss 0.0708088 accuracy 0.6602
# Epoch 145, CIFAR-10 Batch 4:  loss 0.0776803 accuracy 0.6552
# Epoch 145, CIFAR-10 Batch 5:  loss 0.0734251 accuracy 0.6358
# Epoch 146, CIFAR-10 Batch 1:  loss 0.0908184 accuracy 0.6458
# Epoch 146, CIFAR-10 Batch 2:  loss 0.0780777 accuracy 0.6392
# Epoch 146, CIFAR-10 Batch 3:  loss 0.0690217 accuracy 0.6606
# Epoch 146, CIFAR-10 Batch 4:  loss 0.076375 accuracy 0.6544
# Epoch 146, CIFAR-10 Batch 5:  loss 0.0720525 accuracy 0.6364
# Epoch 147, CIFAR-10 Batch 1:  loss 0.0897008 accuracy 0.6462
# Epoch 147, CIFAR-10 Batch 2:  loss 0.0762238 accuracy 0.6368
# Epoch 147, CIFAR-10 Batch 3:  loss 0.0674499 accuracy 0.6612
# Epoch 147, CIFAR-10 Batch 4:  loss 0.0752493 accuracy 0.6552
# Epoch 147, CIFAR-10 Batch 5:  loss 0.0710639 accuracy 0.6376
# Epoch 148, CIFAR-10 Batch 1:  loss 0.0891715 accuracy 0.6458
# Epoch 148, CIFAR-10 Batch 2:  loss 0.0749527 accuracy 0.637
# Epoch 148, CIFAR-10 Batch 3:  loss 0.0660508 accuracy 0.6612
# Epoch 148, CIFAR-10 Batch 4:  loss 0.0742477 accuracy 0.6554
# Epoch 148, CIFAR-10 Batch 5:  loss 0.0703501 accuracy 0.6384
# Epoch 149, CIFAR-10 Batch 1:  loss 0.0892071 accuracy 0.6454
# Epoch 149, CIFAR-10 Batch 2:  loss 0.0741273 accuracy 0.6342
# Epoch 149, CIFAR-10 Batch 3:  loss 0.0648206 accuracy 0.6606
# Epoch 149, CIFAR-10 Batch 4:  loss 0.0735335 accuracy 0.6574
# Epoch 149, CIFAR-10 Batch 5:  loss 0.069959 accuracy 0.6376
# Epoch 150, CIFAR-10 Batch 1:  loss 0.089649 accuracy 0.6428
# Epoch 150, CIFAR-10 Batch 2:  loss 0.0738857 accuracy 0.6332
# Epoch 150, CIFAR-10 Batch 3:  loss 0.0637255 accuracy 0.6616
# Epoch 150, CIFAR-10 Batch 4:  loss 0.0730185 accuracy 0.6564
# Epoch 150, CIFAR-10 Batch 5:  loss 0.0698367 accuracy 0.6376

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6383460640907288

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
